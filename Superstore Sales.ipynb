# %%
## Internship-InnoByte Services

# %%
import pandas as pd 
# Step 1: Read the CSV file using pandas
file_name = 'SampleSuperstore.csv'  
df = pd.read_csv(file_name)

# %%
#Type of the Data Frame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#total no of rows and columns in the data frame 
df[:]
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#Data Exploration
print(df.head())
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB
# None

# %%
print(df.describe())
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# Print column names 
print(df.columns)
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# Data Cleaning

#Check for missing values
print(df.isnull().sum())
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Drop rows with missing values
df = df.dropna()

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 17

# %%
print(df.dtypes)
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
import pandas as pd

df = pd.read_csv('SampleSuperstore.csv')
print('Data loaded successfully.')
print('First 5 rows of the dataset:')
print(df.head())
print('\
Data Types and Missing Values:')
print(df.info())
# Out:
# Data loaded successfully.
# First 5 rows of the dataset:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()
print('Missing values in each column:')
print(missing_values)

# Check for duplicates
print('Number of duplicate rows:', df.duplicated().sum())

# Check for inconsistencies in categorical data
for column in df.select_dtypes(include=['object']).columns:
    print(f'Inconsistencies in {column}:', df[column].apply(lambda x: x.strip()).nunique() - df[column].nunique())

# Convert data types if necessary
# Checking data types that might need conversion
print('Data types before conversion:')
print(df.dtypes)

# Converting 'Postal Code' from float to int
if df['Postal Code'].dtype != 'int':
    df['Postal Code'] = df['Postal Code'].astype(int)
    print('Postal Code converted to int.')

print('Data types after conversion:')
print(df.dtypes)
# Out:
# Missing values in each column:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64
# Number of duplicate rows: 17
# Inconsistencies in Ship Mode: 0
# Inconsistencies in Segment: 0
# Inconsistencies in Country: 0
# Inconsistencies in City: 0
# Inconsistencies in State: 0
# Inconsistencies in Region: 0
# Inconsistencies in Category: 0
# Inconsistencies in Sub-Category: 0
# Data types before conversion:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object
# ...

# %%
# Remove duplicate rows
initial_row_count = len(df)
df = df.drop_duplicates()
final_row_count = len(df)

# Display the result
print('Initial number of rows:', initial_row_count)
print('Number of rows after removing duplicates:', final_row_count)
# Out:
# Initial number of rows: 9994
# Number of rows after removing duplicates: 9977

# %%
print('Summary Statistics for Numerical Columns:')
print(df.describe())

print('Unique Values in Categorical Columns:')
for column in df.select_dtypes(include=['object']).columns:
    print(f'Unique values in {column}:', df[column].nunique())
# Out:
# Summary Statistics for Numerical Columns:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600
# Unique Values in Categorical Columns:
# Unique values in Ship Mode: 4
# Unique values in Segment: 3
# Unique values in Country: 1
# Unique values in City: 531
# Unique values in State: 49
# Unique values in Region: 4
# Unique values in Category: 3
# Unique values in Sub-Category: 17

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Remove duplicates
initial_row_count = len(df)
df = df.drop_duplicates()
final_row_count = len(df)

# Sales by State
plt.figure(figsize=(15, 8), facecolor='white')
sns.barplot(x='State', y='Sales', data=df, estimator=sum, ci=None)
plt.title('Total Sales by State')
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# Profit by State
plt.figure(figsize=(15, 8), facecolor='white')
sns.barplot(x='State', y='Profit', data=df, estimator=sum, ci=None)
plt.title('Total Profit by State')
plt.xlabel('State')
plt.ylabel('Total Profit')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# Correlation matrix
plt.figure(figsize=(10, 8), facecolor='white')
corr = df[['Sales', 'Profit', 'Quantity', 'Discount']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15832\1842175029.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State', y='Sales', data=df, estimator=sum, ci=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_15832\1842175029.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='State', y='Profit', data=df, estimator=sum, ci=None)

# %%
# Additional Descriptive Statistics
skewness = df[['Sales', 'Profit', 'Quantity', 'Discount']].skew()
kurtosis = df[['Sales', 'Profit', 'Quantity', 'Discount']].kurtosis()
range_sales = df['Sales'].max() - df['Sales'].min()
iqr_sales = df['Sales'].quantile(0.75) - df['Sales'].quantile(0.25)
sum_sales = df['Sales'].sum()
unique_states = df['State'].nunique()

(skewness, kurtosis, range_sales, iqr_sales, sum_sales, unique_states)
# Out:
# (Sales       12.963770
#  Profit       7.554748
#  Quantity     1.276709
#  Discount     1.683386
#  dtype: float64,
#  Sales       304.870940
#  Profit      396.515988
#  Quantity      1.983746
#  Discount      2.406089
#  dtype: float64,
#  22638.036,
#  192.67,
#  2296195.5903,
#  49)

# %%
# Setting up the plots
plt.figure(figsize=(18, 12))

# Histogram for Sales
plt.subplot(2, 2, 1)
sns.histplot(df['Sales'], kde=True, color='blue')
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')

# Histogram for Quantity
plt.subplot(2, 2, 2)
sns.histplot(df['Quantity'], kde=True, color='green')
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')

# Boxplot for Sales
plt.subplot(2, 2, 3)
sns.boxplot(x=df['Sales'])
plt.title('Box Plot of Sales')
plt.xlabel('Sales')

# Boxplot for Quantity
plt.subplot(2, 2, 4)
sns.boxplot(x=df['Quantity'])
plt.title('Box Plot of Quantity')
plt.xlabel('Quantity')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
file_path = 'SampleSuperstore.csv'
df = pd.read_csv(file_path, encoding='ascii')

# Calculate Profit Margin as Profit divided by Sales
# Adding a small constant to avoid division by zero
df['Profit Margin'] = df['Profit'] / (df['Sales'] + 1e-6)

# Plotting the distribution of Profit Margin
plt.figure(figsize=(10, 6), facecolor='white')
sns.histplot(df['Profit Margin'], kde=True, color='purple')
plt.title('Distribution of Profit Margin')
plt.xlabel('Profit Margin')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Displaying the head of the dataframe with the new column
print(df[['Profit Margin']].head())
# Out:
#    Profit Margin
# 0         0.1600
# 1         0.3000
# 2         0.4700
# 3        -0.4000
# 4         0.1125

# %%
# Calculating the average profit margin for each sub-category
subcat_profit_margin = df.groupby('Sub-Category')['Profit Margin'].mean().sort_values(ascending=False)

# Displaying the top 5 sub-categories with the highest profit margin
top_5_subcat_profit_margin = subcat_profit_margin.head(5)
print(top_5_subcat_profit_margin)
# Out:
# Sub-Category
# Labels       0.429663
# Paper        0.425600
# Envelopes    0.423140
# Copiers      0.317194
# Fasteners    0.299170
# Name: Profit Margin, dtype: float64

# %%
# Calculating the average profit margin for each sub-category
subcat_profit_margin = df.groupby('Sub-Category')['Profit Margin'].mean().sort_values(ascending=True)

# Displaying the top 5 sub-categories with the lowest profit margin
top_5_subcat_lowest_profit_margin = subcat_profit_margin.head(5)
print(top_5_subcat_lowest_profit_margin)
# Out:
# Sub-Category
# Binders      -0.199595
# Appliances   -0.156869
# Tables       -0.147727
# Bookcases    -0.126640
# Machines     -0.072026
# Name: Profit Margin, dtype: float64

# %%
# Grouping the data by Category to sum the sales
category_sales = df.groupby('Category').agg({'Sales':'sum'}).reset_index()

# Displaying the sales breakdown by category
category_sales
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
# Finding the top-selling products in each category
top_products_by_category = df.groupby(['Category', 'Sub-Category']).agg({'Sales':'sum'}).sort_values(by=['Category', 'Sales'], ascending=[True, False]).groupby('Category').head(1).reset_index()

# Displaying the top-selling products by category
top_products_by_category
# Out:
#           Category Sub-Category       Sales
# 0        Furniture       Chairs  328449.103
# 1  Office Supplies      Storage  223843.608
# 2       Technology       Phones  330007.054

# %%
# Grouping the data by Region to sum the sales
region_sales = df.groupby('Region').agg({'Sales':'sum'}).reset_index()

# Displaying the sales breakdown by region
region_sales
# Out:
#     Region        Sales
# 0  Central  501239.8908
# 1     East  678781.2400
# 2    South  391721.9050
# 3     West  725457.8245

# %%
# Finding the top-selling products in each region
top_products_by_region = df.groupby(['Region', 'Sub-Category']).agg({'Sales':'sum'}).sort_values(by=['Region', 'Sales'], ascending=[True, False]).groupby('Region').head(1).reset_index()

# Displaying the top-selling products by region
top_products_by_region
# Out:
#     Region Sub-Category       Sales
# 0  Central       Chairs   85230.646
# 1     East       Phones  100614.982
# 2    South       Phones   58304.438
# 3     West       Chairs  101781.328

# %%
import pandas as pd

df = pd.read_csv('SampleSuperstore.csv', encoding='ascii')

# Grouping data by 'State' and 'City' to analyze geographic purchasing behavior
df_geo = df.groupby(['State', 'City']).agg({'Sales': 'sum', 'Profit': 'sum', 'Quantity': 'sum'}).reset_index()

# Sorting the data by Sales to see top purchasing cities
df_geo_sorted = df_geo.sort_values(by='Sales', ascending=False).head(10)

print(df_geo_sorted)
# Out:
#             State           City        Sales      Profit  Quantity
# 389      New York  New York City  256368.1610  62036.9837      3417
# 63     California    Los Angeles  175851.3410  30440.7579      2879
# 586    Washington        Seattle  119540.7420  29156.0967      1590
# 90     California  San Francisco  112669.0920  17507.3854      1935
# 463  Pennsylvania   Philadelphia  109077.0130 -13837.7674      1981
# 521         Texas        Houston   64504.7604 -10153.5485      1466
# 201      Illinois        Chicago   48539.5410  -6654.5688      1132
# 89     California      San Diego   47521.0290   6377.1960       670
# 295      Michigan        Detroit   42446.9440  13181.7908       441
# 153       Florida   Jacksonville   39133.3280  -2445.6608       248
